# %% [markdown]
# #Paquetes necesarios

# %%
import cv2  
import math 

from ultralytics import YOLO
import pytesseract

# %% [markdown]
# Desde cámara, detección con yolov8 y modelo nano. Visualización propia

# %%
# Carga del modelo
model = YOLO('./runs/detect/train4/weights/best.pt') #Contenedores

pytesseract.pytesseract.tesseract_cmd = r'C:/Program Files/Tesseract-OCR/tesseract'

# Lenguajes disponibles
print(pytesseract.get_languages(config=''))

# Nombre de las distintas clases
classNames = ['license'
              ]


# Captura desde lawebcam
vid = cv2.VideoCapture(0)
  
while(True):      
    # fotograma a fotograma
    ret, img = vid.read()
  
    # si hay imagen válida
    if ret:  
        # Perform inference on an image
        results = model(img, stream=True)
        
        # Para cada detección
        for r in results:
            boxes = r.boxes

            for box in boxes:
                # Contenedor
                x1, y1, x2, y2 = box.xyxy[0]
                x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2) # convert to int values
                
                # Confianza
                confidence = math.ceil((box.conf[0]*100))/100
                #print("Confidence --->",confidence)

                # Clase
                cls = int(box.cls[0])
                #print("Class name -->", classNames[cls])

                cropped = img[y1:y2,x1:x2]

                

                #Cargo imagen y ocnvierto a RGB
                """ img = cv2.imread('toy.tif') 
                img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) """

                #Aplica reconocedor a imagen cargada
                text = pytesseract.image_to_string(cropped)

                # Convierte identificador numérico de clase a un color RGB
                escala = int((cls / len(classNames)) * 255 * 3)
                if escala >= 255*2:
                    R = 255
                    G = 255
                    B = escala - 255*2
                else:
                    if escala >= 255:
                        R = 255
                        G = escala - 255
                        B = 0
                    else:
                        R = escala
                        G = 0
                        B = 0

                # Dibuja el contenedor y clase
                cv2.rectangle(img, (x1, y1), (x2, y2), (R, G, B), 3)
                cv2.putText(img, text , [x1, y1], cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 255), 2)

        # Muestra fotograma
        cv2.imshow('Vid', img)
    
    # Detenemos pulsado ESC
    if cv2.waitKey(20) == 27:
        break
  
# Libera el objeto de captura
vid.release()
# Destruye ventanas
cv2.destroyAllWindows()
# Out:
# ['eng', 'osd']
# 0: 320x416 (no detections), 108.9ms
# Speed: 0.0ms preprocess, 108.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 189.2ms
# Speed: 2.7ms preprocess, 189.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 122.9ms
# Speed: 0.0ms preprocess, 122.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 114.8ms
# Speed: 4.2ms preprocess, 114.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 98.8ms
# Speed: 2.3ms preprocess, 98.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 89.8ms
# Speed: 2.6ms preprocess, 89.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 95.8ms
# Speed: 3.8ms preprocess, 95.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 97.8ms
# Speed: 6.1ms preprocess, 97.8ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 85.9ms
# Speed: 0.0ms preprocess, 85.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 96.4ms
# Speed: 2.2ms preprocess, 96.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 98.3ms
# Speed: 2.3ms preprocess, 98.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 73.1ms
# Speed: 2.3ms preprocess, 73.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 91.7ms
# Speed: 0.6ms preprocess, 91.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 81.1ms
# Speed: 0.0ms preprocess, 81.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 87.8ms
# Speed: 2.2ms preprocess, 87.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 94.5ms
# Speed: 3.7ms preprocess, 94.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 101.6ms
# Speed: 2.7ms preprocess, 101.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 89.4ms
# Speed: 3.0ms preprocess, 89.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 80.0ms
# Speed: 3.9ms preprocess, 80.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 70.5ms
# Speed: 2.5ms preprocess, 70.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 63.6ms
# Speed: 2.2ms preprocess, 63.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 71.9ms
# Speed: 3.3ms preprocess, 71.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 91.5ms
# Speed: 0.0ms preprocess, 91.5ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 71.8ms
# Speed: 0.0ms preprocess, 71.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 1 license, 73.9ms
# Speed: 5.0ms preprocess, 73.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 2 licenses, 119.9ms
# Speed: 1.1ms preprocess, 119.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 1 license, 109.4ms
# Speed: 6.4ms preprocess, 109.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 1 license, 84.7ms
# Speed: 3.7ms preprocess, 84.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 1 license,
9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 151.2ms
# Speed: 0.0ms preprocess, 151.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 80.3ms
# Speed: 0.0ms preprocess, 80.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 82.1ms
# Speed: 3.4ms preprocess, 82.1ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 85.5ms
# Speed: 1.1ms preprocess, 85.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 75.2ms
# Speed: 2.5ms preprocess, 75.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 87.2ms
# Speed: 2.8ms preprocess, 87.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 85.6ms
# Speed: 2.6ms preprocess, 85.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 73.8ms
# Speed: 1.1ms preprocess, 73.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 72.1ms
# Speed: 2.3ms preprocess, 72.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 83.0ms
# Speed: 0.0ms preprocess, 83.0ms inference, 3.8ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 102.9ms
# Speed: 3.2ms preprocess, 102.9ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 107.8ms
# Speed: 4.3ms preprocess, 107.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 115.3ms
# Speed: 1.1ms preprocess, 115.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 84.0ms
# Speed: 3.8ms preprocess, 84.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 84.0ms
# Speed: 0.0ms preprocess, 84.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 102.3ms
# Speed: 0.0ms preprocess, 102.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 92.5ms
# Speed: 4.8ms preprocess, 92.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 84.8ms
# Speed: 0.0ms preprocess, 84.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 140.4ms
# Speed: 0.0ms preprocess, 140.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 90.6ms
# Speed: 0.0ms preprocess, 90.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 88.2ms
# Speed: 2.5ms preprocess, 88.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 77.8ms
# Speed: 2.3ms preprocess, 77.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 68.3ms
# Speed: 1.0ms preprocess, 68.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 87.5ms
# Speed: 3.9ms preprocess, 87.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 135.7ms
# Speed: 6.2ms preprocess, 135.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 143.0ms
# Speed: 1.0ms preprocess, 143.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 103.7ms
# Speed: 0.0ms preprocess, 103.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 113.0ms
# Speed: 1.3ms preprocess, 113.0ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 109.6ms
# Speed: 4.6ms preprocess, 109.6ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 101.6ms
# Speed: 4.6ms preprocess, 101.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 142.0ms
# Speed: 1.5ms preprocess, 142.0ms inference, 5.8ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 85.8ms
# Speed: 3.3ms preprocess, 85.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 89.8ms
# Speed: 0.0ms preprocess, 89.8ms inference, 5.5ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 80.4ms
# Speed: 5.2ms preprocess, 80.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 90.8ms
# Speed: 1.3ms preprocess, 90.8ms inference, 3.7ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 320x416 (no detections), 83.2ms
# Speed: 3.6ms preprocess, 83.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 416)

# %% [markdown]
# Diversos modelos preentrenados, visualizando

# %%
# Carga del modelo
#model = YOLO('yolov8n.pt') #Contenedores
#model = YOLO('yolov8n-seg.pt') #Máscaras
model = YOLO('yolov8n-pose.pt')  #Pose

#Para un vídeo 
filename = "C:/Users/otsed/Desktop/RUNNERS_ILUSOS/Multimedia/Bibs/TGC23_PdH_C0056_resultado.mp4"
results = model(filename, show=True)

# %% [markdown]
# Reconocimiento de caracteres tras instalar pytesseract y tesseract

# %%
# Tesseract
import cv2
import pytesseract

# Previamente debes descargar los ejecutables
# Si la ruta de Tesseract no está en el PATH, ruta al ejecutable
pytesseract.pytesseract.tesseract_cmd = r'C:/Program Files/Tesseract-OCR/tesseract'

# Lenguajes disponibles
print(pytesseract.get_languages(config=''))

#Cargo imagen y ocnvierto a RGB
img = cv2.imread('toy.tif') 
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

#Aplica reconocedor a imagen cargada
print(pytesseract.image_to_string(img_rgb))

# %% [markdown]
# Reconocimiento decaracteres tras instalar easyocr

# %%
import easyocr

#Carga del modelo de lengua
reader = easyocr.Reader(['es']) 

#Reconocimiento de una imagen
result = reader.readtext('toy.tif')
print(result)

#Con restricción de caracteres reconocibles
#result = reader.readtext('toy.tif', allowlist ='0123456789')
